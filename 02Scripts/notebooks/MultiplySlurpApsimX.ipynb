# %% [markdown]
# ## Aim:
#
# 1. Replace the R script to muliply apsimx files via the Edit feature.
# 2. First step is to figure out the critical parameters that need to be changed.
# 3. Second step is to change the general parameters,
#     such as Weather, Clock, SowingDates, MaximumHeight, Coverfile path
# 4. Third step is to setup the combination of soil parameters.
#
# There are two ways to do the multiplication:
# 1. Edit only the sowing rules based on the current slurp setup.
# 2. Provide all possible combinations of skl, klr, rfv and modify a trimmed version slurp to have one apsimx file for one set of parameters.
#
# A combination of both might be more suitable for Richard's data.
# Because:
# The parameter **Depth** does not match the current slurp setup.
# There will be multiple paths to modify all kls

# %%
#load packages
import sqlite3
import re
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import math

# %% [markdown]
# # Try call edit in python to see if it speeds up than R

# %%
os.system('cp C:/Data/Master/01raw-data/ApsimxFiles/20200517BaseSlurp.apsimx \
            C:/Data/Master/03processed-data/apsimxFiles/test.apsimx ')
# Out:
# 0

# %%
con = sqlite3.connect('../03processed-data/Richard.sqlite3')
mycur = con.cursor() 
mycur.execute("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;")
(mycur.fetchall())
# Out:
# [('ES',),
#  ('Phenology',),
#  ('SoilWater',),
#  ('SowingDates',),
#  ('biomass',),
#  ('met_AshleyDene',),
#  ('met_Iversen12',),
#  ('root',)]

# %%
water = pd.read_sql('Select * from SoilWater',  con)
water = water.drop(['Season','Rep', 'Plot', 'Seed', 'DAS','SWC'], axis = 1)

# %%
water['SW(1)']
y = [str(x) for x in water['SW(1)']]
# [a for a in y.str not in '[]' ]
[str(a) for a in y  if a not in "["]
# Out:
# ['17.4',
#  '21.1',
#  '17.9',
#  '25.2',
#  '18.4',
#  '19.9',
#  '27.0',
#  '16.9',
#  '12.5',
#  '16.9',
#  '15.3',
#  '23.0',
#  '16.8',
#  '15.0',
#  '25.0',
#  '15.7',
#  '10.3',
#  '17.6',
#  '17.3',
#  '23.3',
#  '19.9',
#  '19.8',
#  '23.6',
#  '16.6',
#  '8.3',
#  '14.3',
#  '13.9',
#  '21.2',
#  '17.1',
#  '15.1',
#  '24.1',
#  '14.6',
#  '8.7',
#  '12.0',
#  '11.1',
#  '15.8',
#  '14.2',
#  '12.1',
#  '21.5',
#  '9.6',
#  '18.7',
#  '13.0',
#  '14.3',
#  '7.3',
#  '7.3',
#  '10.3',
#  '9.8',
#  '10.1',
#  '9.4',
#  '10.3',
#  '21.7',
#  '8.6',
#  '12.3',
#  '17.5',
#  '13.1',
#  '7.8',
#  '7.3',
#  '12.4',
#  '10.9',
#  '12.1',
#  '15.1',
#  '13.1',
#  '21.9',
#  '11.5',
#  '16.9',
#  '21.8',
#  '17.5',
#  '12.9',
#  '4.9',
#  '10.3',
#  '8.5',
#  '12.6',
#  '9.8',
#  '11.7',
#  '20.0',
#  '9.9',
#  '16.2',
#  '21.2',
#  '14.9',
#  '12.0',
#  '3.9',
#  '11.3',
#  '9.7',
#  '11.9',
#  '12.0',
#  '9.1',
#  '19.4',
#  '10.6',
#  '17.1',
#  '22.2',
#  '17.4',
#  '13.6',
#  '19.3',
#  '21.0',
#  '20.9',
#  '16.2',
#  '4.7',
#  '8.2',
#  '6.6',
#  '8.9',
#  '8.4',
#  '5.9',
#  '9.0',
#  '7.3',
#  '12.8',
#  '18.7',
#  '15.0',
#  '8.2',
#  '16.2',
#  '18.4',
#  '18.6',
#  '13.1',
#  '3.6',
#  '8.1',
#  '7.5',
#  '8.9',
#  '8.1',
#  '7.0',
#  '11.1',
#  '8.6',
#  '11.3',
#  '10.4',
#  '10.8',
#  '9.0',
#  '9.1',
#  '18.0',
#  '15.6',
#  '16.4',
#  '17.6',
#  '11.9',
#  '19.4',
#  '17.9',
#  '3.3',
#  '7.4',
#  '6.4',
#  '8.2',
#  '7.6',
#  '6.0',
#  '14.4',
#  '7.5',
#  '7.4',
#  '12.7',
#  '7.7',
#  '6.0',
#  '12.8',
#  '14.9',
#  '16.8',
#  '10.9',
#  '16.1',
#  '13.2',
#  '18.3',
#  '16.6',
#  '4.2',
#  '8.3',
#  '6.9',
#  '9.1',
#  '8.0',
#  '6.8',
#  '15.0',
#  '7.7',
#  '7.7',
#  '12.1',
#  '7.9',
#  '6.7',
#  '10.6',
#  '17.3',
#  '18.4',
#  '10.5',
#  '16.9',
#  '14.7',
#  '20.3',
#  '17.2',
#  '6.2',
#  '9.2',
#  '8.2',
#  '10.4',
#  '8.3',
#  '8.1',
#  '15.6',
#  '8.0',
#  '7.8',
#  '13.0',
#  '8.8',
#  '8.5',
#  '12.8',
#  '17.1',
#  '18.5',
#  '10.3',
#  '16.5',
#  '14.2',
#  '16.7',
#  '18.2',
#  '20.3',
#  '23.3',
#  '22.3',
#  '24.3',
#  '22.2',
#  '22.9',
#  '26.0',
#  '20.5',
#  '21.7',
#  '26.9',
#  '25.4',
#  '20.4',
#  '26.7',
#  '29.2',
#  '30.5',
#  '22.0',
#  '26.3',
#  '24.6',
#  '25.6',
#  '25.7',
#  '21.4',
#  '25.3',
#  '26.4',
#  '27.3',
#  '24.4',
#  '25.5',
#  '27.9',
#  '23.5',
#  '25.8',
#  '28.2',
#  '26.0',
#  '24.0',
#  '28.6',
#  '30.5',
#  '30.7',
#  '25.3',
#  '27.0',
#  '25.2',
#  '29.9',
#  '23.4',
#  '16.0',
#  '20.8',
#  '21.9',
#  '25.3',
#  '18.0',
#  '19.3',
#  '24.6',
#  '18.0',
#  '22.5',
#  '25.0',
#  '24.3',
#  '20.7',
#  '25.6',
#  '26.9',
#  '28.0',
#  '22.5',
#  '24.5',
#  '21.6',
#  '26.3',
#  '25.1',
#  '21.8',
#  '22.2',
#  '26.1',
#  '27.0',
#  '23.4',
#  '22.6',
#  '28.8',
#  '23.8',
#  '26.7',
#  '27.1',
#  '26.9',
#  '23.1',
#  '26.9',
#  '27.4',
#  '31.6',
#  '23.9',
#  '26.2',
#  '25.1',
#  '30.2',
#  '25.9',
#  '16.8',
#  '20.0',
#  '20.8',
#  '24.2',
#  '19.8',
#  '20.2',
#  '26.0',
#  '16.8',
#  '21.6',
#  '25.1',
#  '24.1',
#  '19.3',
#  '22.5',
#  '25.5',
#  '27.4',
#  '18.1',
#  '20.9',
#  '18.8',
#  '26.9',
#  '22.0',
#  '20.4',
#  '24.4',
#  '24.3',
#  '26.0',
#  '22.2',
#  '23.0',
#  '29.3',
#  '21.1',
#  '25.3',
#  '26.6',
#  '23.4',
#  '22.5',
#  '25.1',
#  '26.9',
#  '30.4',
#  '22.9',
#  '24.8',
#  '24.3',
#  '29.7',
#  '24.8',
#  '22.3',
#  '26.3',
#  '25.8',
#  '27.7',
#  '24.7',
#  '25.4',
#  '31.5',
#  '24.2',
#  '27.2',
#  '29.4',
#  '25.8',
#  '23.1',
#  '26.8',
#  '28.9',
#  '31.9',
#  '27.5',
#  '26.4',
#  '25.6',
#  '26.8',
#  '26.2',
#  '23.1',
#  '26.2',
#  '28.5',
#  '28.4',
#  '25.6',
#  '26.7',
#  '31.3',
#  '24.6',
#  '28.4',
#  '28.8',
#  '25.9',
#  '24.1',
#  '25.4',
#  '27.5',
#  '33.4',
#  '27.3',
#  '28.0',
#  '26.6',
#  '32.3',
#  '26.3',
#  '22.0',
#  '27.7',
#  '27.8',
#  '28.5',
#  '26.1',
#  '25.4',
#  '32.7',
#  '23.6',
#  '28.3',
#  '29.7',
#  '29.0',
#  '24.2',
#  '28.5',
#  '30.7',
#  '33.4',
#  '27.4',
#  '26.7',
#  '26.5',
#  '32.2',
#  '26.5',
#  '17.7',
#  '23.9',
#  '22.2',
#  '25.6',
#  '21.7',
#  '21.6',
#  '29.2',
#  '19.4',
#  '23.0',
#  '25.8',
#  '23.8',
#  '20.6',
#  '24.4',
#  '27.0',
#  '28.5',
#  '22.9',
#  '22.5',
#  '22.8',
#  '28.9',
#  '24.1',
#  '16.5',
#  '21.7',
#  '20.7',
#  '23.6',
#  '20.1',
#  '20.5',
#  '27.9',
#  '18.0',
#  '21.7',
#  '24.8',
#  '22.1',
#  '19.0',
#  '22.1',
#  '25.1',
#  '27.5',
#  '21.4',
#  '21.5',
#  '21.5',
#  '27.4',
#  '22.5',
#  '14.2',
#  '20.3',
#  '19.5',
#  '22.5',
#  '19.2',
#  '18.7',
#  '28.4',
#  '15.9',
#  '20.9',
#  '23.3',
#  '22.0',
#  '19.1',
#  '22.5',
#  '23.6',
#  '26.5',
#  '19.2',
#  '18.1',
#  '21.0',
#  '26.8',
#  '20.9',
#  '12.1',
#  '17.4',
#  '15.4',
#  '21.1',
#  '18.1',
#  '17.3',
#  '25.8',
#  '14.0',
#  '17.8',
#  '20.7',
#  '19.0',
#  '16.3',
#  '18.7',
#  '20.0',
#  '23.7',
#  '16.3',
#  '17.4',
#  '19.2',
#  '24.3',
#  '18.3',
#  '20.2',
#  '24.0',
#  '21.9',
#  '26.3',
#  '23.9',
#  '24.1',
#  '30.3',
#  '22.0',
#  '25.1',
#  '26.6',
#  '25.6',
#  '22.8',
#  '25.5',
#  '27.4',
#  '28.8',
#  '22.9',
#  '21.6',
#  '25.4',
#  '30.4',
#  '24.5',
#  '19.5',
#  '24.5',
#  '25.2',
#  '27.2',
#  '25.4',
#  '23.7',
#  '31.1',
#  '22.3',
#  '24.5',
#  '26.9',
#  '24.7',
#  '20.4',
#  '24.4',
#  '27.5',
#  '30.3',
#  '22.4',
#  '21.6',
#  '24.3',
#  '29.9',
#  '27.2',
#  '8.4',
#  '16.7',
#  '16.7',
#  '20.4',
#  '18.6',
#  '14.5',
#  '29.8',
#  '12.5',
#  '16.7',
#  '21.1',
#  '18.5',
#  '11.7',
#  '16.2',
#  '19.4',
#  '21.2',
#  '15.2',
#  '14.0',
#  '16.2',
#  '16.1',
#  '16.4',
#  '16.1',
#  '19.3',
#  '19.0',
#  '20.8',
#  '19.7',
#  '18.7',
#  '25.9',
#  '13.2',
#  '18.9',
#  '19.9',
#  '20.4',
#  '17.1',
#  '16.8',
#  '19.4',
#  '20.2',
#  '13.3',
#  '18.5',
#  '18.7',
#  '21.6',
#  '11.0',
#  '11.7',
#  '13.1',
#  '14.1',
#  '15.3',
#  '14.7',
#  '12.3',
#  '20.3',
#  '9.3',
#  '12.0',
#  '14.6',
#  '9.9',
#  '11.0',
#  '10.6',
#  '14.2',
#  '14.1',
#  '9.7',
#  '11.0',
#  '13.2',
#  '14.7',
#  '7.2',
#  '15.0',
#  '15.5',
#  '17.9',
#  '19.7',
#  '16.8',
#  '16.2',
#  '20.6',
#  '11.8',
#  '14.7',
#  '16.9',
#  '15.8',
#  '15.3',
#  '15.3',
#  '17.5',
#  '17.9',
#  '13.6',
#  '15.2',
#  '17.9',
#  '20.1',
#  '10.8',
#  '13.0',
#  '15.4',
#  '16.2',
#  '18.4',
#  '16.2',
#  '15.4',
#  '16.1',
#  '10.4',
#  '13.5',
#  '14.4',
#  '15.5',
#  '13.8',
#  '15.7',
#  '15.2',
#  '12.1',
#  '10.6',
#  '11.3',
#  '16.1',
#  '11.4',
#  '10.5',
#  '6.9',
#  '8.4',
#  '8.9',
#  '9.6',
#  '9.2',
#  '7.7',
#  '13.7',
#  '6.3',
#  '7.5',
#  '9.7',
#  '8.9',
#  '7.4',
#  '7.0',
#  '8.4',
#  '9.5',
#  '6.3',
#  '6.4',
#  '8.9',
#  '9.2',
#  '6.4',
#  '6.3',
#  '7.5',
#  '7.8',
#  '8.4',
#  '8.0',
#  '6.9',
#  '11.6',
#  '5.9',
#  '6.8',
#  '8.4',
#  '7.4',
#  '6.9',
#  '6.3',
#  '7.5',
#  '8.2',
#  '5.9',
#  '6.2',
#  '7.2',
#  '7.8',
#  '5.4',
#  '8.1',
#  '10.6',
#  '11.0',
#  '11.0',
#  '11.3',
#  '8.8',
#  '12.8',
#  '9.0',
#  '9.2',
#  '10.4',
#  '10.0',
#  '11.2',
#  '9.6',
#  '9.6',
#  '11.9',
#  '7.6',
#  '8.2',
#  '9.8',
#  '11.1',
#  '9.4',
#  '10.4',
#  '11.3',
#  '11.5',
#  '13.0',
#  '12.4',
#  '11.8',
#  '14.0',
#  '10.0',
#  '10.8',
#  '12.0',
#  '11.9',
#  '10.9',
#  '10.3',
#  '11.0',
#  '12.7',
#  '9.3',
#  '10.2',
#  '11.8',
#  '12.0',
#  '6.4',
#  '12.6',
#  '16.1',
#  '16.3',
#  '18.8',
#  '17.3',
#  '14.9',
#  '16.9',
#  '13.4',
#  '16.8',
#  '15.3',
#  '16.7',
#  '16.2',
#  '14.9',
#  '13.7',
#  '15.2',
#  '11.9',
#  '14.5',
#  '16.5',
#  '18.2',
#  '13.4',
#  '18.1',
#  '20.7',
#  '21.5',
#  '25.0',
#  '20.7',
#  '20.5',
#  '22.9',
#  '15.7',
#  '18.3',
#  '21.0',
#  '21.2',
#  '20.1',
#  '20.8',
#  '20.3',
#  '22.6',
#  '17.9',
#  '19.9',
#  '21.7',
#  '22.5',
#  '15.0',
#  '12.6',
#  '16.5',
#  '17.9',
#  '20.2',
#  '19.2',
#  '14.9',
#  '20.6',
#  '15.3',
#  '15.5',
#  '17.7',
#  '16.8',
#  '14.1',
#  '18.5',
#  '16.4',
#  '18.0',
#  '14.2',
#  '16.0',
#  '17.5',
#  '18.7',
#  '11.0',
#  '7.7',
#  '9.9',
#  '11.9',
#  '9.9',
#  '11.1',
#  '9.3',
#  '13.3',
#  '7.8',
#  '8.6',
#  '11.2',
#  '10.3',
#  '7.9',
#  '10.1',
#  '10.1',
#  '11.2',
#  '8.3',
#  '9.1',
#  '10.2',
#  '11.0',
#  '7.7',
#  '14.9',
#  '12.6',
#  '16.1',
#  '11.4',
#  '15.8',
#  '15.0',
#  '18.9',
#  '14.0',
#  '10.3',
#  '14.6',
#  '8.9',
#  '15.6',
#  '15.1',
#  '15.1',
#  '16.7',
#  '14.7',
#  '15.9',
#  '14.0',
#  '16.4',
#  '9.9',
#  '10.4',
#  '12.5',
#  '12.1',
#  '12.6',
#  '13.2',
#  '11.9',
#  '15.4',
#  '10.7',
#  '11.0',
#  '12.0',
#  '10.5',
#  '11.0',
#  '12.7',
#  '12.0',
#  '13.4',
#  '10.5',
#  '11.8',
#  '13.1',
#  '12.8',
#  '9.8',
#  '14.2',
#  '11.0',
#  '10.2',
#  '11.5',
#  '8.6',
#  '10.1',
#  '13.1',
#  '8.0',
#  '9.8',
#  '11.2',
#  '8.1',
#  '8.2',
#  '9.6',
#  '9.5',
#  '11.4',
#  '8.1',
#  '9.7',
#  '11.4',
#  '10.3',
#  '6.8',
#  '9.6',
#  '13.7',
#  '12.4',
#  '13.6',
#  '13.8',
#  '12.3',
#  '16.8',
#  '10.3',
#  '14.5',
#  '14.4',
#  '11.7',
#  '12.6',
#  '11.5',
#  '11.3',
#  '12.8',
#  '10.0',
#  '12.6',
#  '12.7',
#  '10.6',
#  '7.8',
#  '23.6',
#  '26.6',
#  '27.7',
#  '24.5',
#  '26.1',
#  '21.9',
#  '30.0',
#  '25.8',
#  '28.1',
#  '27.2',
#  '22.4',
#  '25.7',
#  '26.3',
#  '26.4',
#  '29.4',
#  '25.2',
#  '25.4',
#  '27.1',
#  '28.1',
#  '22.2',
#  '25.4',
#  '27.0',
#  '27.8',
#  '27.9',
#  '27.2',
#  '25.4',
#  '32.6',
#  '24.9',
#  '28.4',
#  '27.2',
#  '26.5',
#  '24.8',
#  '26.3',
#  '26.4',
#  '28.6',
#  '22.8',
#  '26.3',
#  '27.8',
#  '28.8',
#  '24.2',
#  '14.4',
#  '20.4',
#  '23.2',
#  '15.8',
#  '20.8',
#  '25.0',
#  '27.0',
#  '20.5',
#  '19.0',
#  '23.9',
#  '25.0',
#  '18.3',
#  '15.3',
#  '21.8',
#  '20.7',
#  '13.6',
#  '13.7',
#  '20.5',
#  '20.7',
#  '13.9',
#  '17.6',
#  '18.4',
#  '22.2',
#  '19.1',
#  '17.9',
#  '24.4',
#  '24.2',
#  '20.5',
#  '22.5',
#  '21.6',
#  '25.2',
#  '22.3',
#  '16.1',
#  '17.3',
#  '21.3',
#  '17.0',
#  '19.2',
#  '20.6',
#  '24.7',
#  '16.9',
#  '23.2',
#  '21.4',
#  '26.5',
#  '21.8',
#  '15.9',
#  '23.7',
#  '21.4',
#  '15.0',
#  '16.3',
#  '17.7',
#  '19.1',
#  '15.4',
#  '20.8',
#  '20.7',
#  '24.8',
#  '20.2',
#  '17.0',
#  '21.5',
#  '22.9',
#  '15.1',
#  '7.1',
#  '8.1',
#  '8.6',
#  '7.5',
#  '9.7',
#  '9.9',
#  '15.5',
#  '9.1',
#  '13.3',
#  '20.1',
#  '19.2',
#  '9.3',
#  '17.1',
#  '20.1',
#  '17.3',
#  '12.3',
#  '6.6',
#  '7.8',
#  '8.4',
#  '7.0',
#  '8.7',
#  '8.4',
#  '11.7',
#  '7.4',
#  '9.6',
#  '17.1',
#  '11.1',
#  '8.0',
#  '18.3',
#  '21.3',
#  '17.4',
#  '11.6',
#  '12.0',
#  '12.3',
#  '14.5',
#  '12.6',
#  '8.8',
#  '11.2',
#  '13.2',
#  '11.2',
#  '11.7',
#  '14.4',
#  '12.9',
#  '9.9',
#  '18.5',
#  '21.5',
#  '20.0',
#  '14.7',
#  '10.3',
#  '12.4',
#  '13.7',
#  '13.6',
#  '12.7',
#  '10.1',
#  '14.3',
#  '12.2',
#  '12.0',
#  '12.9',
#  '12.8',
#  '10.1',
#  '20.7',
#  '25.1',
#  '23.0',
#  '17.8',
#  '20.1',
#  '18.3',
#  '16.9',
#  '19.7',
#  ...]

# %%
water['Clock.Today'] = pd.to_datetime(water['Clock.Today'])

# %%
# indexing
water = water.pivot_table(index = 'Clock.Today', 
                          columns=['Experiment', 'SowingDate'])

# %%
# Rename the indexs
water.columns.set_names('Depth', level=0, inplace=True)
water.columns
# Out:
# MultiIndex([('SW(1)', 'AshleyDene',  'SD1'),
#             ('SW(1)', 'AshleyDene', 'SD10'),
#             ('SW(1)', 'AshleyDene',  'SD2'),
#             ('SW(1)', 'AshleyDene',  'SD3'),
#             ('SW(1)', 'AshleyDene',  'SD4'),
#             ('SW(1)', 'AshleyDene',  'SD5'),
#             ('SW(1)', 'AshleyDene',  'SD6'),
#             ('SW(1)', 'AshleyDene',  'SD7'),
#             ('SW(1)', 'AshleyDene',  'SD8'),
#             ('SW(1)', 'AshleyDene',  'SD9'),
#             ...
#             ('SW(9)',  'Iversen12',  'SD1'),
#             ('SW(9)',  'Iversen12', 'SD10'),
#             ('SW(9)',  'Iversen12',  'SD2'),
#             ('SW(9)',  'Iversen12',  'SD3'),
#             ('SW(9)',  'Iversen12',  'SD4'),
#             ('SW(9)',  'Iversen12',  'SD5'),
#             ('SW(9)',  'Iversen12',  'SD6'),
#             ('SW(9)',  'Iversen12',  'SD7'),
#             ('SW(9)',  'Iversen12',  'SD8'),
#             ('SW(9)',  'Iversen12',  'SD9')],
#            names=['Depth', 'Experiment', 'SowingDate'], length=460)

# %%
AD = water.filter(regex='Ash')

# %%
SowingDates.AD = pd.to_datetime(SowingDates.AD)
ADSD = SowingDates.loc[:,['AD']].set_index('AD')
ADSD
# Out:
# Empty DataFrame
# Columns: []
# Index: [2010-10-21 00:00:00, 2010-11-09 00:00:00, 2010-12-08 00:00:00, 2011-01-13 00:00:00, 2011-02-03 00:00:00, 2011-10-10 00:00:00, 2011-11-07 00:00:00, 2011-12-09 00:00:00, 2012-01-10 00:00:00, 2012-02-17 00:00:00]

# %%
test = water.stack().reset_index('SowingDate')
test
# Out:
# Depth       SowingDate      SW(1)               SW(10)                SW(11)  \
# Experiment             AshleyDene Iversen12 AshleyDene  Iversen12 AshleyDene
# Clock.Today
# 2010-10-04         SD1        NaN   24.4375        NaN  29.737500        NaN
# 2010-11-07         SD2        NaN   37.5500        NaN  32.300000        NaN
# 2010-11-09         SD1     20.400       NaN  10.125000        NaN   9.675000
# 2010-11-09         SD2     20.550       NaN   9.512500        NaN   8.733333
# 2010-11-16         SD1     16.925       NaN  10.125000        NaN   9.675000
# ...                ...        ...       ...        ...        ...        ...
# 2012-07-12         SD1     27.025   31.3500  10.258970  15.798134  10.117417
# 2012-07-12         SD2     27.525   33.9500   8.617785  15.477369   8.713053
# 2012-07-12         SD3     26.725   34.3750   9.693781  13.819046   9.712001
# 2012-07-12         SD4     26.025   33.3250  10.081971  11.643555  10.277973
# 2012-07-12         SD5     26.775   33.3250   9.976413  10.703515  10.306053
#
# Depth                      SW(12)                SW(13)  ...      SW(5)  \
# Experiment   Iversen12 AshleyDene  Iversen12 AshleyDene  ... AshleyDene
# Clock.Today                                              ...
# 2010-10-04   31.600000        NaN  30.862500        NaN  ...        NaN
# 2010-11-07   32.650000        NaN  31.775000        NaN  ...        NaN
# 2010-11-09         NaN   9.566667        NaN   9.983333  ...  10.987500
# 2010-11-09         NaN   9.037500        NaN   9.512500  ...  11.437500
# 2010-11-16         NaN   9.566667        NaN   9.983333  ...  10.987500
# ...                ...        ...        ...        ...  ...        ...
# 2012-07-12   13.802965  10.515580  11.898018  10.937942  ...  12.507679
# 2012-07-12   16.375567   9.002520  14.914502   9.298873  ...  12.113551
# 2012-07-12   11.877661  10.011075  10.650952  10.317968  ...  13.467418
# 2012-07-12    8.834491  10.656218   9.858525  11.042251  ...  12.718977
# 2012-07-12   14.254444  10.016752  12.687165   9.734606  ...  11.974454
#
# Depth                       SW(6)                 SW(7)                 SW(8)  \
# Experiment   Iversen12 AshleyDene  Iversen12 AshleyDene  Iversen12 AshleyDene
# Clock.Today
# 2010-10-04   26.250000        NaN  27.012500        NaN  29.237500        NaN
# 2010-11-07   20.600000        NaN  20.325000        NaN  24.125000        NaN
# 2010-11-09         NaN  10.237500        NaN   9.837500        NaN   9.987500
# 2010-11-09         NaN  10.300000        NaN  10.100000        NaN   9.575000
# 2010-11-16         NaN  10.237500        NaN   9.837500        NaN   9.987500
# ...                ...        ...        ...        ...        ...        ...
# 2012-07-12   22.752681  11.826762  21.270136  11.042039  17.038894  11.132101
# 2012-07-12   25.550316  11.312237  24.862137  10.436897  20.724628   9.506494
# 2012-07-12   26.399688  11.942856  25.758929  11.547449  22.128188  11.216957
# 2012-07-12   22.365564  11.460772  19.641506  10.798474  15.049302  10.517676
# 2012-07-12   25.292672  11.072835  22.590500  10.346008  19.169730   9.837641
#
# Depth                       SW(9)
# Experiment   Iversen12 AshleyDene  Iversen12
# Clock.Today
# 2010-10-04   30.612500        NaN  31.387500
# 2010-11-07   27.687500        NaN  30.150000
# 2010-11-09         NaN  10.300000        NaN
# 2010-11-09         NaN   9.291667        NaN
# 2010-11-16         NaN  10.300000        NaN
# ...                ...        ...        ...
# 2012-07-12   14.404833  10.820058  14.250229
# 2012-07-12   17.493417   9.371624  15.418443
# 2012-07-12   19.657516  10.197305  16.176761
# 2012-07-12   14.535333  10.319041  13.617989
# 2012-07-12   14.841761   9.470730  11.006047
#
# [456 rows x 47 columns]

# %%
pd.merge_asof( ADSD,water,  left_index=True, right_index=True, direction='nearest').filter(regex='Ash').stack().reset_index('AD')
# Out:
#                                   AD        0
# (SW(1), AshleyDene, SD1)  2010-11-09  20.4000
# (SW(1), AshleyDene, SD2)  2010-11-09  20.5500
# (SW(10), AshleyDene, SD1) 2010-11-09  10.1250
# (SW(10), AshleyDene, SD2) 2010-11-09   9.5125
# (SW(11), AshleyDene, SD1) 2010-11-09   9.6750
# ...                              ...      ...
# (SW(5), AshleyDene, SD10) 2012-02-17  11.3250
# (SW(6), AshleyDene, SD10) 2012-02-17   9.0250
# (SW(7), AshleyDene, SD10) 2012-02-17   8.2375
# (SW(8), AshleyDene, SD10) 2012-02-17   7.9000
# (SW(9), AshleyDene, SD10) 2012-02-17   7.5250
#
# [276 rows x 2 columns]

# %%
SD.pivot_table(index = 'Clock.Today', columns=['Experiment', 'SowingDate'], )
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-151-56c1aed4b023> in <module>
# ----> 1 SD.pivot_table(index = 'Clock.Today', columns=['Experiment', 'SowingDate'])
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6078             dropna=dropna,
#    6079             margins_name=margins_name,
# -> 6080             observed=observed,
#    6081         )
#    6082
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      99
#     100     grouped = data.groupby(keys, observed=observed)
# --> 101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     103         agged = agged.dropna(how="all")
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     926         func = _maybe_mangle_lambdas(func)
#     927
# --> 928         result, how = self._aggregate(func, *args, **kwargs)
#     929         if how is None:
#     930             return result
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     309
#     310         if isinstance(arg, str):
# --> 311             return self._try_aggregate_string_function(arg, *args, **kwargs), None
#     312
#     313         if isinstance(arg, dict):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\base.py in _try_aggregate_string_function(self, arg, *args, **kwargs)
#     265         if f is not None:
#     266             if callable(f):
# --> 267                 return f(*args, **kwargs)
#     268
#     269             # people may try to aggregate on a non-callable attribute
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1223         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
#    1224         return self._cython_agg_general(
# -> 1225             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1226         )
#    1227
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     992     ) -> DataFrame:
#     993         agg_blocks, agg_items = self._cython_agg_blocks(
# --> 994             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     995         )
#     996         return self._wrap_agged_blocks(agg_blocks, items=agg_items)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1093
#    1094         if not (agg_blocks or split_frames):
# -> 1095             raise DataError("No numeric types to aggregate")
#    1096
#    1097         if split_items:
#
# DataError: No numeric types to aggregate

# %%
# Check unique values in the factors 
# print (water.apply(lambda x: x.nunique()))

for i in water.columns[0:8:2]:
    print(water.loc[:, i].unique())
# Out:
# ['AshleyDene' 'Iversen12']
# ['2010/11' '2011/12']
# [1. 2. 3. 4.]
# ['CS']

# %%
# indexing 
water = water.set_index(['Experiment', 'Clock.Today', 'SowingDate'
                        ]).drop(['Season','Rep', 'Plot', 'Seed', 'DAS','SWC'
                                ], axis = 1)

# %% [markdown]
# ## # Initial soil water
# ### Bring in the sowing dates data

# %%
SowingDates = pd.read_sql('Select * from SowingDates',  con)

# %%
SD = SowingDates.melt(id_vars = 'SD')
SD.columns = ['SowingDate', 'Experiment', 'Clock.Today']
SD.loc[SD['Experiment'] == 'AD', 'Experiment'] = 'AshleyDene'
SD.loc[SD['Experiment'] == 'I12', 'Experiment'] = 'Iversen12'
SD['Clock.Today'] = pd.to_datetime(SD['Clock.Today'])
# SD = SD.set_index(['SowingDate', 'Experiment', 'Clock.Today'])
SD
# Out:
#    SowingDate  Experiment Clock.Today
# 0         SD1  AshleyDene  2010-10-21
# 1         SD2  AshleyDene  2010-11-09
# 2         SD3  AshleyDene  2010-12-08
# 3         SD4  AshleyDene  2011-01-13
# 4         SD5  AshleyDene  2011-02-03
# 5         SD6  AshleyDene  2011-10-10
# 6         SD7  AshleyDene  2011-11-07
# 7         SD8  AshleyDene  2011-12-09
# 8         SD9  AshleyDene  2012-01-10
# 9        SD10  AshleyDene  2012-02-17
# 10        SD1   Iversen12  2010-10-04
# 11        SD2   Iversen12  2010-11-04
# 12        SD3   Iversen12  2010-12-02
# 13        SD4   Iversen12  2011-01-10
# 14        SD5   Iversen12  2011-02-07
# 15        SD6   Iversen12  2011-10-10
# 16        SD7   Iversen12  2011-11-07
# 17        SD8   Iversen12  2011-12-09
# 18        SD9   Iversen12  2012-01-10
# 19       SD10   Iversen12  2012-02-17

# %%
SWmean = water.groupby(['Experiment', 'Clock.Today', 'SowingDate'
                       ]).mean().reset_index()

# %%
# SWmean = SWmean.reindex(sorted(SWmean.columns), axis=1)
SD = SD.reindex(sorted(SD.columns), axis=1).set_index(['Clock.Today'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-4f54534dd62c> in <module>
#       1 SWmean = SWmean.reindex(sorted(SWmean.columns), axis=1)
# ----> 2 SD = SD.reindex(sorted(SD.columns), axis=1).set_index(['Clock.Today'])
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Clock.Today'] are in the columns"

# %%
SWmean.loc[SWmean['Experiment'],].index.get_loc('2010-10-21', method = 'nearest')
# Out:
#              Experiment SowingDate   SW(1)   SW(2)      SW(3)      SW(4)  \
# Clock.Today
# 2010-11-09   AshleyDene        SD1  20.400  20.400  16.800000  13.375000
# 2010-11-09   AshleyDene        SD2  20.550  20.550  18.875000  14.262500
# 2010-11-16   AshleyDene        SD1  16.925  16.925  16.800000  13.375000
# 2010-11-16   AshleyDene        SD2  18.125  18.125  18.875000  14.262500
# 2010-11-24   AshleyDene        SD1  17.125  17.125  17.025000  13.725000
# ...                 ...        ...     ...     ...        ...        ...
# 2012-07-12   AshleyDene        SD1  27.025  27.025  17.919765  14.525151
# 2012-07-12   AshleyDene        SD2  27.525  27.525  20.757333  15.200673
# 2012-07-12   AshleyDene        SD3  26.725  26.725  19.402622  15.157370
# 2012-07-12   AshleyDene        SD4  26.025  26.025  19.626519  15.260070
# 2012-07-12   AshleyDene        SD5  26.775  26.775  17.318881  14.077165
#
#                  SW(5)      SW(6)      SW(7)      SW(8)  ...     SW(14)  \
# Clock.Today                                              ...
# 2010-11-09   10.987500  10.237500   9.837500   9.987500  ...  10.633333
# 2010-11-09   11.437500  10.300000  10.100000   9.575000  ...  10.204167
# 2010-11-16   10.987500  10.237500   9.837500   9.987500  ...  10.633333
# 2010-11-16   11.437500  10.300000  10.100000   9.575000  ...  10.120833
# 2010-11-24   11.050000  10.400000   9.725000  10.175000  ...  10.333333
# ...                ...        ...        ...        ...  ...        ...
# 2012-07-12   12.507679  11.826762  11.042039  11.132101  ...  11.048355
# 2012-07-12   12.113551  11.312237  10.436897   9.506494  ...   9.179560
# 2012-07-12   13.467418  11.942856  11.547449  11.216957  ...  10.262212
# 2012-07-12   12.718977  11.460772  10.798474  10.517676  ...  10.570450
# 2012-07-12   11.974454  11.072835  10.346008   9.837641  ...  10.049556
#
#                 SW(15)     SW(16)     SW(17)     SW(18)     SW(19)     SW(20)  \
# Clock.Today
# 2010-11-09   10.612500  11.437500  11.700000  11.150000  10.937500  10.987500
# 2010-11-09   10.287500   9.766667   9.541667   9.420833  10.212500  10.679167
# 2010-11-16   10.612500  11.437500  11.700000  11.150000  10.937500  10.987500
# 2010-11-16   10.304167   9.929167   9.512500   9.670833  10.141667  10.437500
# 2010-11-24   11.612500  11.887500  12.400000  11.750000  11.487500  11.237500
# ...                ...        ...        ...        ...        ...        ...
# 2012-07-12   11.162215  10.936958  10.715749  10.238141   9.774411   9.613701
# 2012-07-12    9.072182   8.381527   7.724510   7.865482   8.016736   8.333014
# 2012-07-12   10.215995   9.575531   8.955347   9.271781   9.594781   9.999233
# 2012-07-12   10.128252  10.159549  10.196336  10.595106  11.021937  10.790480
# 2012-07-12   10.227058  10.262099  10.175598   9.719393   9.279245   8.688053
#
#                 SW(21)     SW(22)     SW(23)
# Clock.Today
# 2010-11-09   11.012500  11.362500  11.781250
# 2010-11-09   10.704167  10.949306  11.405035
# 2010-11-16   11.012500  11.362500  11.781250
# 2010-11-16   10.837500  10.741667  11.326042
# 2010-11-24   11.462500  12.262500  14.306250
# ...                ...        ...        ...
# 2012-07-12    9.456728  10.068340  10.648862
# 2012-07-12    8.654471   9.563204  10.816617
# 2012-07-12   10.433735  10.488916   9.899838
# 2012-07-12   10.562831  10.679803  10.802378
# 2012-07-12    8.653590   8.993063   9.369616
#
# [295 rows x 25 columns]

# %%
# https://janakiev.com/blog/python-shell-commands/
